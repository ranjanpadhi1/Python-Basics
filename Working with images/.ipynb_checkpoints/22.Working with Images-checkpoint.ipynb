# %%
from PIL import Image

dog = Image.open('dog.jpg')

# %%
dog
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x479>

# %%
dog.size
# Out:
# (612, 479)

# %%
dog.crop((80, 320, 190, 440))
# Out:
# <PIL.Image.Image image mode=RGB size=110x120>

# %%
small_dog = dog.crop((80, 320, 190, 440))

# %%
dog.paste(im=small_dog, box=(180,320))

# %%
dog
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x479>
